# %%
import sys
# !{sys.executable} -m pip install requests

# %%
import requests
import pandas as pd
import json
from pathlib import Path  

auth = "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwYWI1ZDQ5YzBhYzkxY2YyZmMwYTllZDYyYTU5MzVkMCIsIm5iZiI6MTYzOTI0MTUzMi44NzY5OTk5LCJzdWIiOiI2MWI0ZDczYzAzNzI2NDAwMWNhOTBhMmUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.3I_5_g-feDx2U_IAW3IpN68TYMlVtkxaKucOQ1TpDqc"

# %%
#get data

columns = ['title', 'adult', 'backdrop_path', 'genre_ids', 'id', 'original_language',
       'original_title', 'overview', 'popularity', 'poster_path',
       'release_date', 'video', 'vote_average', 'vote_count']
df = pd.DataFrame(columns = columns)


for i in range(100):
    
    url = f"https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={i}"
    
    headers = {
        "accept": "application/json",
        "Authorization": auth
    }
    response = requests.get(url, headers=headers)
    df = pd.concat([df, pd.DataFrame(data=json.loads(response.text).get('results'))])
# Out:
# C:\Users\icest\AppData\Local\Temp\ipykernel_25044\2428514806.py:18: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame(data=json.loads(response.text).get('results'))])

# %%
filePath = Path('data/popularmovies.csv')  
filePath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filePath)

# %%
df
# Out:
#                                  title  adult  \
# 0             The Shawshank Redemption  False
# 1                        The Godfather  False
# 2                The Godfather Part II  False
# 3                     Schindler's List  False
# 4                         12 Angry Men  False
# ..                                 ...    ...
# 15  Batman Beyond: Return of the Joker  False
# 16                          Crossroads  False
# 17                              Carrie  False
# 18                      Phantom Thread  False
# 19                            Brothers  False
#
#                        backdrop_path                 genre_ids      id  \
# 0   /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg                  [18, 80]     278
# 1   /tmU7GeKVybMWFButWEGl2M4GeiP.jpg                  [18, 80]     238
# 2   /kGzFbGhp99zva6oZODW5atUtnqi.jpg                  [18, 80]     240
# 3   /zb6fM1CX41D9rF9hdgclu0peUmy.jpg           [18, 36, 10752]     424
# ...
